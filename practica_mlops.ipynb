# %% [markdown]
# # Práctica Final: Clasificación con Scikit-learn y MLflow

# %% [markdown]
# ![runs.png](attachment:runs.png)

# %% [markdown]
# ![Models.png](attachment:Models.png)

# %% [markdown]
# ![Logistic_Regression.png](attachment:Logistic_Regression.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![Random_Forest.png](attachment:Random_Forest.png)

# %% [markdown]
# ![Random_Forest_Metrics.png](attachment:Random_Forest_Metrics.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Generar .py de funciones y main con al menos dos argumentos de entrada.

# %% [markdown]
# ### Archivo con funciones para mlflow
#
# [mlflow_tracker.py](mlflow/mlflow_tracker.py)

# %% [markdown]
# ### Archivo main
#
# [main.py](mlflow/main.py)

# %% [markdown]
# ## Práctica parte FastAPI

# %% [markdown]
# ### Para esta parte de la práctica teneis que generar un script con al menos 5 modulos app.get y dos de ellos tienen que ser pipelines de HF.
#
# ### Parte de la practica se tendra que entregar en capturas de pantalla. Las capturas de pantalla a adjuntas son las siguientes.
#
# ### 1. Captura de la pantalla docs con al menos 5 modulos.
# ### 2. Captura de cada una de los modulos con la respuesta dentro de docs.
# ### 3. Captura de cada uno de los modulos en la llamada https.
# ### 4. Todo el codigo usado durante el proceso. Notebooks y scripts.
#
# ### Opcional
#
# ### 5. Despliegue del script en GCP Cloud Run

# %% [markdown]
# ##### Get /saludo
# ![image.png](attachment:image.png)

# %% [markdown]
# ##### Post /user-info
# ![image.png](attachment:image.png)

# %% [markdown]
# ##### Get /read-dataframe
# ![image.png](attachment:image.png)

# %% [markdown]
# ##### Get /get-gdp
# ![image.png](attachment:image.png)

# %% [markdown]
# ##### Get /paraphrase
# - Modelo extraido de: [ramsrigouthamg/t5_paraphraser](https://huggingface.co/ramsrigouthamg/t5_paraphraser)
# - ![image.png](attachment:image.png)

# %% [markdown]
# ##### Get /translate
# - Modelo extraido de: [Helsinki-NLP/opus-mt-en-es](https://huggingface.co/Helsinki-NLP/opus-mt-en-es)
# - ![image.png](attachment:image.png)
